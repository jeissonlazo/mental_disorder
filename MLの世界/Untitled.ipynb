# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split




# Cargar el conjunto de datos Iris
iris = datasets.load_iris()

# Crear un DataFrame con las características (X)
X = iris.data[:, :2]  # Tomamos solo las dos primeras características
df_X = pd.DataFrame(X, columns=['feature1', 'feature2'])

# Crear un DataFrame con las etiquetas (y)
y = iris.target
df_y = pd.DataFrame(y, columns=['target'])

# Concatenar los DataFrames de características y etiquetas
df_iris = pd.concat([df_X, df_y], axis=1)


#X y y

X=df_iris[['feature1', 'feature2']]
y=df_iris[['target']]


#dividiendo los datos
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# Train SVM model
clf = svm.SVC(kernel='linear')
clf.fit(X, y)

# Create meshgrid
x_min, x_max = X.iloc[:, 0].min() - 1, X.iloc[:, 0].max() + 1
y_min, y_max = X.iloc[:, 1].min() - 1, X.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))

# Predict classes for each point in meshgrid
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

#mapeo
color_map = {0: 'red', 1: 'green', 2: 'blue'}
colors = df_iris['target'].map(color_map)

# Plot decision boundary
plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8)
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=colors, cmap=plt.cm.coolwarm)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.title('SVM Decision Boundary')
plt.show()
# Out:
# C:\Users\Nicol\anaconda3\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Nicol\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\Nicol\AppData\Local\Temp\ipykernel_16500\755934905.py:54: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=colors, cmap=plt.cm.coolwarm)

# %%
df_iris
# Out:
#      feature1  feature2  target
# 0         5.1       3.5       0
# 1         4.9       3.0       0
# 2         4.7       3.2       0
# 3         4.6       3.1       0
# 4         5.0       3.6       0
# ..        ...       ...     ...
# 145       6.7       3.0       2
# 146       6.3       2.5       2
# 147       6.5       3.0       2
# 148       6.2       3.4       2
# 149       5.9       3.0       2
#
# [150 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# Supongamos que tienes dos características binarias: A y B
A = [0, 1, 0, 1, 1]
B = [1, 0, 1, 1, 0]
clases = [0, 1, 1, 0, 1]  # Supongamos que estas son las clases correspondientes

# Preparar datos para gráfico de barras
categorias = ['A=0', 'A=1']
valores_A = [A.count(0), A.count(1)]
valores_B = [B.count(0), B.count(1)]

# Graficar
plt.bar(categorias, valores_A, alpha=0.5, label='A')
plt.bar(categorias, valores_B, alpha=0.5, label='B')
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.title('Distribución de características binarias')
plt.legend()
plt.show()
